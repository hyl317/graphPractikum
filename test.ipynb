# %%
from src.erdbeermet.simulation import load
from src.erdbeermet.recognition import recognize, recognize_and_compare
    
basepath = f'./simulations/N6/default'
scenario = load(f'{basepath}/hist_rep373.txt')
recognition_tree = recognize_and_compare(scenario,first_candidate_only=True, print_info=True)
print(recognition_tree)
recognition_tree = recognition_tree[0]
recognition_tree.visualize(save_as='default_833.pdf')
# Out:
# -----> n = 6, V = [0, 1, 2, 3, 4, 5] ---> Candidates
# (0, 1: 2) alpha=[0.71506427 0.71506427 0.71506427]   δx = 0.054, δy = 1.029, δz = 0.605, dxy = 0.964
# (3, 4: 5) alpha=[0.37596076 0.37596076 0.37596076]   δx = 0.005, δy = 0.039, δz = 0.154, dxy = 1.031
# -----> n = 6, V = [0, 1, 2, 3, 4, 5] ---> R-steps actually carried out
# (0, 1: 2) alpha=0.71506   δx = 0.054, δy = 1.029, δz = 0.605, dxy = 0.964
#          |___ STACKED [0, 1, 3, 4, 5]
# -----> n = 5, V = [0, 1, 3, 4, 5] ---> Candidates
# (0, 1: 5) alpha=[0.69502931]   δx = 0.385, δy = 0.219, δz = 0.320, dxy = 0.360
# (0, 3: 1) alpha=[0.52906659]   δx = 0.503, δy = 0.005, δz = 0.248, dxy = 0.452
# (0, 3: 5) alpha=[0.7717869]   δx = 0.430, δy = 0.283, δz = 0.329, dxy = 0.247
# (0, 4: 5) alpha=[0.94319409]   δx = 0.503, δy = 2.220, δz = 0.437, dxy = -2.200
# (1, 4: 0) alpha=[0.44152545]   δx = 0.449, δy = 0.039, δz = 0.362, dxy = 0.275
# (1, 4: 3) alpha=[0.92301003]   δx = 0.219, δy = 2.220, δz = 0.402, dxy = -1.675
# ...
